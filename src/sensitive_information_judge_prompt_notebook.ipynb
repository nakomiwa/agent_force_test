# %% [markdown]
# # ライブラリ準備

# %%
# 必要なライブラリをバージョン固定でインストール
# !pip install openai==2.5.0 mlflow==3.5.0 pyyaml==6.0.2
dbutils.library.restartPython()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 必要なクラスをインポート
from base_prompt import BacePrompt
from sensitive_information_judge_prompt import SensitiveInformationJudgePrompt

# %% [markdown]
# # 機微情報判断プロンプトクラスのインスタンスを作成

# %%
prompt = SensitiveInformationJudgePrompt(experiment_base_path="/Workspace/b_poc/b_0048/experiments")

# %% [markdown]
# # サンプルデータを作成

# %%
# サンプルデータを作成
prompt.create_sample_data()

# %% [markdown]
# # ダミーデータを作成

# %%
prompt.create_dummy_data()

# %% [markdown]
# # LLMによる機微情報判断

# %%
prompt.generate()
